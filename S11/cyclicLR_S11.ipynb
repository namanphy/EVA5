# %% [markdown]
# <a href="https://colab.research.google.com/github/namanphy/EVA5/blob/main/S11/cyclicLR_S11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

! git clone https://github.com/namanphy/EVA5.git
sys.path.append('EVA5/S11/')
# Out:
# Cloning into 'EVA5'...
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 714 (delta 126), reused 193 (delta 98), pack-reused 486
# Receiving objects: 100% (714/714), 3.79 MiB | 6.19 MiB/s, done.
# Resolving deltas: 100% (405/405), done.

# %%
from engine.utils import CyclicLR

# %%
clr = CyclicLR(500, 100, 0.004, 0.02)
clr.cyclic_lr(plot=True)
